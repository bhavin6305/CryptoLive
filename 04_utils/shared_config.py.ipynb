# %%
# Shared configuration — imported/run by every other notebook in this project

CATALOG = "workspace"
SCHEMA = "crypto_live"
VOLUME_NAME = "raw_landing"
VOLUME_PATH = f"/Volumes/{CATALOG}/{SCHEMA}/{VOLUME_NAME}"

# The coins we're tracking — CoinGecko's internal IDs (not ticker symbols)
COIN_IDS = [
    "bitcoin", "ethereum", "tether", "binancecoin", "solana",
    "ripple", "cardano", "dogecoin", "polkadot", "litecoin"
]

print(f"Config loaded. Landing zone: {VOLUME_PATH}")
# Out:
# Config loaded. Landing zone: /Volumes/workspace/crypto_live/raw_landing
